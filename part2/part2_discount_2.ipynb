# %% [markdown]
# # PART 2 :  SARSA Implementation by minazmeh and nagasita

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
class TreasureHuntEnv:
    def __init__(self):
        self.action_space = ['Up', 'Down', 'Left', 'Right']
        self.state_space = [(x, y) for x in range(5) for y in range(5)]
        self.rewards = {
            (1, 1): 1,
            (4, 2): 3,
            (2, 3): 1,
            (2, 0): -1,
            (4, 4): 50 
        }
        self.current_state = (0, 0)
    def step(self, action):
        x, y = self.current_state
        if action == 'Up':
            x = max(0, x - 1)
        elif action == 'Down':
            x = min(4, x + 1)
        elif action == 'Left':
            y = max(0, y - 1)
        elif action == 'Right':
            y = min(4, y + 1)

        self.current_state = (x, y)
        reward = self.rewards.get(self.current_state, 0) - 1
        done = self.current_state == (4, 4)
        return self.current_state, reward, done

    def reset(self):
        self.current_state = (0, 0)
        return self.current_state
    
    def render(self):
        grid = np.zeros((5, 5)) 
        x, y = self.current_state 

        plt.figure(figsize=(10, 10))  
        for i in range(5):
            for j in range(5):
                if (i, j) == (4, 4):  
                    if (i, j) == self.current_state:
                        continue
                    plt.text(j + 0.5, 4 - i + 0.5, "Goal", ha='center', va='center',
                             color="blue", fontsize=20, fontweight='bold')
                    
                elif (i, j) in self.rewards:
                    if (i, j) == self.current_state: 
                        continue
                    if self.rewards[(i, j)] > 0:
                        plt.text(j + 0.5, 4 - i + 0.5, "Gold", ha='center', va='center',
                                 color="orange", fontsize=20, fontweight='bold')
                    elif self.rewards[(i, j)] < 0:
                        plt.text(j + 0.5, 4 - i + 0.5, "Trap", ha='center', va='center',
                                 color="red", fontsize=20, fontweight='bold')

        if self.current_state in self.rewards:
            if self.rewards[self.current_state] == 50:  
                agent_color = "blue"
                cell_color = "black"  
            elif self.rewards[self.current_state] > 0:  
                agent_color = "orange"
                cell_color = "black"  
            elif self.rewards[self.current_state] < 0:  
                agent_color = "red"
                cell_color = "black"
        else:
            agent_color = "black"  
            cell_color = None

        if cell_color:
            plt.gca().add_patch(plt.Rectangle((y, 4 - x), 1, 1, color=cell_color))

        plt.text(y + 0.5, 4 - x + 0.5, "Agent", ha='center', va='center',
                 color=agent_color, fontsize=20, fontweight='bold')

        for i in range(6):
            plt.axhline(i, color='black', linewidth=1.5)
            plt.axvline(i, color='black', linewidth=1.5)

        plt.xlim(0, 5)
        plt.ylim(0, 5)

        plt.gca().set_aspect('equal', adjustable='box') 
        plt.gca().set_xticks([]) 
        plt.gca().set_yticks([])
        plt.title("Treasure Hunt", fontsize=18, fontweight='bold')
        plt.show()




env = TreasureHuntEnv()
state = env.reset()
print("Initial State:")
env.render()
# Out:
# Initial State:

# %%
#10 timesteps
for t in range(10):
    action = random.choice(env.action_space) #random choice
    next_state, reward, done = env.step(action)
    print(f"Step {t+1}:")
    print(f"Action: {action}")
    print(f"Next State: {next_state}")
    print(f"Reward: {reward}")
    env.render()
    if done:
        print("Reached the goal!")
        break
# Out:
# Step 1:
# Action: Up
# Next State: (0, 0)
# Reward: -1
# Step 2:
# Action: Right
# Next State: (0, 1)
# Reward: -1
# Step 3:
# Action: Right
# Next State: (0, 2)
# Reward: -1
# Step 4:
# Action: Left
# Next State: (0, 1)
# Reward: -1
# Step 5:
# Action: Up
# Next State: (0, 1)
# Reward: -1
# Step 6:
# Action: Up
# Next State: (0, 1)
# Reward: -1
# Step 7:
# Action: Up
# Next State: (0, 1)
# Reward: -1
# Step 8:
# Action: Up
# Next State: (0, 1)
# Reward: -1
# Step 9:
# Action: Left
# Next State: (0, 0)
# Reward: -1
# Step 10:
# Action: Down
# Next State: (1, 0)
# Reward: -1

# %%
class SARSAAgent:
    def __init__(self, env, alpha=0.1, gamma=0.99, epsilon=1.0, epsilon_decay=0.99,min_epsilon=0.01):
        self.env = env
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.min_epsilon = min_epsilon
        self.Q = {state: {action: 0 for action in env.action_space} for state in env.state_space}
        print("Initial Q-values:")
        for state in self.Q:
            print(f"State {state}: {self.Q[state]}")

    def epsilon_greedy_policy(self, state):
        if random.random() < self.epsilon:
            return random.choice(self.env.action_space)
        else:
            return max(self.Q[state], key=self.Q[state].get)

    def train(self, episodes):
        rewards_per_episode = []
        epsilon_values = []

        for episode in range(episodes):
            state = self.env.reset()
            action = self.epsilon_greedy_policy(state)
            total_reward = 0

            while True:
                next_state, reward, done = self.env.step(action)
                next_action = self.epsilon_greedy_policy(next_state)

                self.Q[state][action] += self.alpha * (
                    reward + self.gamma * self.Q[next_state][next_action] - self.Q[state][action]
                )

                total_reward += reward
                state, action = next_state, next_action

                if done:
                    break

            rewards_per_episode.append(total_reward)
            epsilon_values.append(self.epsilon)
            self.epsilon = max(self.min_epsilon, self.epsilon * self.epsilon_decay)

        return rewards_per_episode, epsilon_values

    def evaluate(self, episodes, max_steps=100):
        print('Start evaluation')
        rewards = []
        comments = []

        for episode in range(episodes):
            state = self.env.reset()
            total_reward = 0
            success = False
            steps = 0

            while steps < max_steps:
                steps += 1
                action = max(self.Q[state], key=self.Q[state].get)
                next_state, reward, done = self.env.step(action)
                total_reward += reward
                state = next_state

                if done:
                    success = True
                    break

            rewards.append(total_reward)
            if success:
                comments.append(f"Episode {episode + 1}: SUCCESS - Goal reached in {steps} steps with total reward {total_reward}.")
            else:
                comments.append(f"Episode {episode + 1}: FAIL - Goal not reached in {steps} steps (max steps reached).")

        for comment in comments:
            print(comment)

        return rewards, comments

env = TreasureHuntEnv()
agent = SARSAAgent(env, alpha=0.8, gamma=0.9, epsilon=1, epsilon_decay=0.99,min_epsilon=0.2)

episodes = 1000
rewards_per_episode, epsilon_values = agent.train(episodes)
# Out:
# Initial Q-values:
# State (0, 0): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (0, 1): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (0, 2): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (0, 3): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (0, 4): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (1, 0): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (1, 1): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (1, 2): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (1, 3): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (1, 4): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (2, 0): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (2, 1): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (2, 2): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (2, 3): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (2, 4): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (3, 0): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (3, 1): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (3, 2): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (3, 3): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (3, 4): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (4, 0): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (4, 1): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (4, 2): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (4, 3): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}
# State (4, 4): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}

# %%
evaluation_episodes = 40
evaluation_rewards, evaluation_comments = agent.evaluate(evaluation_episodes, max_steps=1000)
# Out:
# Start evaluation
# Episode 1: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 2: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 3: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 4: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 5: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 6: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 7: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 8: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 9: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 10: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 11: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 12: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 13: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 14: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 15: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 16: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 17: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 18: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 19: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 20: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 21: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 22: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 23: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 24: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 25: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 26: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 27: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 28: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 29: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 30: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 31: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 32: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 33: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 34: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 35: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 36: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 37: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 38: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 39: SUCCESS - Goal reached in 8 steps with total reward 43.
# Episode 40: SUCCESS - Goal reached in 8 steps with total reward 43.

# %%
print("Trained Q-table:")
for state, actions in agent.Q.items():
    print(f"{state}: {actions}")

plt.figure(figsize=(10, 5))
plt.plot(rewards_per_episode, label="Total Reward per Episode")
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(epsilon_values, label="Epsilon Decay")
plt.xlabel('Episode')
plt.ylabel('Epsilon Value')
plt.title('Epsilon Decay over Episodes')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(evaluation_rewards, label="Greedy Policy Rewards")
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Greedy Policy Evaluation')
plt.legend()
plt.grid()
plt.show()
# Out:
# Trained Q-table:
# (0, 0): {'Up': 8.743318842149517, 'Down': 5.2744405021893535, 'Left': 8.389833261080929, 'Right': 12.155054547315107}
# (0, 1): {'Up': 6.54030213617794, 'Down': 18.76020547828172, 'Left': 5.04771954839733, 'Right': 5.706618466146264}
# (0, 2): {'Up': 10.479766280826162, 'Down': 11.339576217601376, 'Left': 16.454352465297426, 'Right': 20.089069352632364}
# (0, 3): {'Up': 21.811297349672877, 'Down': 29.343569467410223, 'Left': 10.240944122059418, 'Right': 22.146734899836794}
# (0, 4): {'Up': 14.118785460674689, 'Down': 31.814881594192784, 'Left': 5.8459260633301735, 'Right': 16.896216278839393}
# (1, 0): {'Up': 11.861082603694655, 'Down': 4.899160872466965, 'Left': 6.979170913080084, 'Right': 10.989770557351445}
# (1, 1): {'Up': 10.329514681242639, 'Down': 5.7296881845585474, 'Left': 11.175941015709665, 'Right': 22.504099528664256}
# (1, 2): {'Up': 18.38373956818691, 'Down': 30.505427549247464, 'Left': 11.117564322887075, 'Right': 15.264707549735235}
# (1, 3): {'Up': 8.050950833136362, 'Down': 33.26061055775585, 'Left': 20.627025554231643, 'Right': 22.97703190034182}
# (1, 4): {'Up': 22.870467113121244, 'Down': 37.751686718595394, 'Left': 29.302979802298022, 'Right': 28.669561282567237}
# (2, 0): {'Up': 17.2547228474751, 'Down': 17.941216780511954, 'Left': 9.024395393142619, 'Right': 26.006486067112597}
# (2, 1): {'Up': 8.640594656465165, 'Down': 1.4440053132473818, 'Left': 9.82402631721024, 'Right': 30.88528960660864}
# (2, 2): {'Up': 16.577065229157828, 'Down': 31.92751290553689, 'Left': 13.946998582824772, 'Right': 18.459129340872515}
# (2, 3): {'Up': 22.747824855327337, 'Down': 30.315985382082307, 'Left': 25.919276811437648, 'Right': 28.24893680783088}
# (2, 4): {'Up': 32.240623019829385, 'Down': 29.00690150405137, 'Left': 28.91418221260855, 'Right': 32.97405962168487}
# (3, 0): {'Up': 19.15437635678716, 'Down': 23.744677795227147, 'Left': 20.81424329104584, 'Right': 20.861329638329465}
# (3, 1): {'Up': 15.334617794061117, 'Down': 34.607201418776484, 'Left': 12.4735709356317, 'Right': 35.69852156327945}
# (3, 2): {'Up': 19.134151703360338, 'Down': 29.760834118995643, 'Left': 27.278880030349743, 'Right': 37.06177632775026}
# (3, 3): {'Up': 28.743259980256944, 'Down': 43.01793400305338, 'Left': 23.186195767246392, 'Right': 30.7143159576201}
# (3, 4): {'Up': 33.62654293516654, 'Down': 49.0, 'Left': 33.67831089535391, 'Right': 43.0996741717474}
# (4, 0): {'Up': 5.999787493274374, 'Down': 3.91953386550007, 'Left': 3.4404299546280592, 'Right': 28.466698408507202}
# (4, 1): {'Up': 16.10874004223771, 'Down': 22.45570471076563, 'Left': 12.04777324366655, 'Right': 26.161905716572107}
# (4, 2): {'Up': 29.114887219002497, 'Down': 38.49402728022892, 'Left': 26.073874329569097, 'Right': 43.09917820352518}
# (4, 3): {'Up': 30.994460911672583, 'Down': 42.24414694370937, 'Left': 30.16817908534764, 'Right': 49.0}
# (4, 4): {'Up': 0, 'Down': 0, 'Left': 0, 'Right': 0}

# %% [markdown]
# # Refrences:

# %% [markdown]
# https://www.restack.io/p/reinforcement-learning-answer-gridworld-example-python-cat-ai
#
# https://ubuffalo-my.sharepoint.com/personal/avereshc_buffalo_edu/_layouts/15/onedrive.aspx?ga=1&id=%2Fpersonal%2Favereshc%5Fbuffalo%5Fedu%2FDocuments%2F2024%5FFall%5FRL%2F%5Fpublic%2FCourse%20Materials%2FRL%20Environment%20Demo
#
# https://www.supplychaindataanalytics.com/visualizing-2d-grids-and-arrays-using-matplotlib-in-python/
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.Rectangle.html
#
# https://www.geeksforgeeks.org/matplotlib-pyplot-gca-in-python/
# https://www.geeksforgeeks.org/sarsa-reinforcement-learning/
#
# https://www.datacamp.com/tutorial/sarsa-reinforcement-learning-algorithm-in-python
